# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import os
from AdvancedLaneDetection.LaneModelling import *
# %matplotlib inline

# %%
img = cv2.imread('test_images/output/test1.png')
img = img[0:240, 640:, :]
print(img.shape)
#create binary image
img[(img < 127)]=0
img[(img >= 127)]=255
plt.imshow(img)
# Out:
# (240, 640, 3)

# %%
bin_img = img[:,:,0]
plt.imshow(bin_img, cmap="gray")
plt.show()
out_image, lane = detectLanes(img[:,:,0], 100, 24, 30, num_white = 50)
plt.figure(figsize=(12,12))
plt.imshow(out_image, cmap="gray")
# Out:
# 239 229 121
# 229 219 125
# 219 209 122
# 209 199 121
# 199 189 119
# 189 179 120
# 179 169 121
# 169 159 121
# 159 149 123
# 149 139 123
# 139 129 127
# 129 119 129
# 119 109 132
# 109 99 133
# 99 89 132
# 89 79 134
# 79 69 139
# 69 59 144
# 59 49 147
# 49 39 145
# 39 29 147
# 29 19 153
# 19 9 155
# 9 -1 155

# %%
out_img, lane_eq = fitLine(img, lane, degree=2)
plt.figure(figsize=(12,12))
plt.imshow(out_img)

# %%
bin_img = img[:,:,0]
plt.imshow(bin_img, cmap="gray")
plt.show()
out_image, lane = detectLanes(img[:,:,0], 100, 24, 30, num_white = 50, side='right')
plt.figure(figsize=(20,20))
plt.imshow(out_image, cmap="gray")
# Out:
# 239 215 558
# 215 191 562
# 191 167 562
# 167 143 578
# 143 119 578
# 119 95 584
# 95 71 590
# 71 47 596
# 47 23 596
# 23 -1 613

# %%
out_img, lane_eq = fitLine(img, lane, degree=2)
plt.figure(figsize=(12,12))
plt.imshow(out_img)

# %%
out_img, lane = trackLanes(bin_img, lane_eq, 20)

# %%
plt.figure(figsize=(12,12))
plt.imshow(out_img)
